# %% [markdown]
# # 1)  import the dependencies

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
import numpy as np
import os
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 2) Opening the Pre-processed Data

# %%
action_path = "E:\PreProcessedData"
X = np.load(os.path.join(action_path,"Sequence.npy"))
y = np.load(os.path.join(action_path,"labels.npy"))

# %%
X.shape
# Out:
# (288, 40, 258)

# %%
y.shape
# Out:
# (288, 288)

# %% [markdown]
# # 3) Training the model

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(40,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(288, activation='softmax'))
# Out:
# C:\Documents\anaco\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X, y, epochs=1000)
# Out:
# Epoch 1/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - categorical_accuracy: 0.0000e+00 - loss: 5.6663
# Epoch 2/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - categorical_accuracy: 0.0000e+00 - loss: 5.6645
# Epoch 3/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - categorical_accuracy: 0.0045 - loss: 5.6635
# Epoch 4/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - categorical_accuracy: 0.0000e+00 - loss: 5.6627
# Epoch 5/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - categorical_accuracy: 0.0027 - loss: 5.6665
# Epoch 6/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - categorical_accuracy: 0.0011 - loss: 5.6599
# Epoch 7/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - categorical_accuracy: 0.0061 - loss: 5.6603
# Epoch 8/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - categorical_accuracy: 0.0035 - loss: 5.6587
# Epoch 9/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - categorical_accuracy: 0.0061 - loss: 5.6500
# Epoch 10/1000
# ...

# %% [markdown]
# # 4) Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 40, 64)         │        82,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 40, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
p = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
actions = os.listdir("E:\Dataset")
temp = []
for action in actions:
    if len(os.listdir(os.path.join("E:\Dataset", action)))<40:
        temp.append(action)
        print(action)
for a in temp:
    actions.remove(a)
# Out:
# because
# believe
# better
# count
# email
# farther
# find
# fit
# Follow
# good
# hear
# Iam
# if
# last
# lead
# life
# money
# next
# overlook
# plan
# prepare
# ready
# safe
# Send
# silent
# something
# start
# story
# Talk
# word
# worse

# %%
actions[np.argmax(p[4])]
# Out:
# 'include'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'include'

# %%
for i in p:
    print(actions[np.argmax(i)])
# Out:
# drink
# wish
# house
# important
# include
# gone
# study
# run
# where
# match
# get
# close
# right
# hello
# you

# %%
for i in y_test:
    print(actions[np.argmax(i)])
# Out:
# drink
# wish
# house
# important
# include
# gone
# study
# run
# where
# match
# get
# close
# right
# hello
# you

# %% [markdown]
# # 5) Saving the model

# %%
model.save("E:/Model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
